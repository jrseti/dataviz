# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Read in the CSV file
file = "Resources/zoo.csv"
df = pd.read_csv(file)
df
# Out:
#       animal  uniq_id   water_need gender
# 0   elephant     1001        500.0      F
# 1   elephant     1002        600.0      F
# 2   elephant     1003        550.0      M
# 3      tiger     1004        300.0      M
# 4      tiger     1005        320.0      F
# 5      tiger     1006        330.0      F
# 6      tiger     1007        290.0      M
# 7      tiger     1008        310.0      F
# 8      zebra     1009  200000000.0      F
# 9      zebra     1010        220.0      M
# 10     zebra     1011        240.0      F
# 11     zebra     1012        230.0      F
# 12     zebra     1013        220.0      F
# 13     zebra     2013          NaN      F
# 14     zebra     1014        100.0      M
# 15     zebra     1015         80.0      M
# 16      lion     1016        420.0      F
# 17      lion     1017        600.0      F
# 18      lion     1018        500.0      F
# 19      lion     1019        390.0      M
# 20  kangaroo     1020        410.0    NaN
# 21  kangaroo     1021        430.0      F
# 22  kangaroo     1022        410.0      M

# %%
# Count all the items in the colums. The count "should" be the same for
# all columns, but notice they are not the same.
#This means there is bad data somewhere that we need to clean.
df.count()
# Out:
# animal        23
# uniq_id       23
# water_need    22
# gender        22
# dtype: int64

# %%
# Remove any roes with a NaN (something that is not a number)
df = df.dropna()
df
# Out:
#       animal  uniq_id   water_need gender
# 0   elephant     1001        500.0      F
# 1   elephant     1002        600.0      F
# 2   elephant     1003        550.0      M
# 3      tiger     1004        300.0      M
# 4      tiger     1005        320.0      F
# 5      tiger     1006        330.0      F
# 6      tiger     1007        290.0      M
# 7      tiger     1008        310.0      F
# 8      zebra     1009  200000000.0      F
# 9      zebra     1010        220.0      M
# 10     zebra     1011        240.0      F
# 11     zebra     1012        230.0      F
# 12     zebra     1013        220.0      F
# 14     zebra     1014        100.0      M
# 15     zebra     1015         80.0      M
# 16      lion     1016        420.0      F
# 17      lion     1017        600.0      F
# 18      lion     1018        500.0      F
# 19      lion     1019        390.0      M
# 21  kangaroo     1021        430.0      F
# 22  kangaroo     1022        410.0      M

# %%
# Look at the averages, do they seem reasonable?
# No! the average is really large. There must be a
# really large number somewhere.
df.describe()
# Out:
#            uniq_id    water_need
# count    21.000000  2.100000e+01
# mean   1011.095238  9.524145e+06
# std       6.363213  4.364350e+07
# min    1001.000000  8.000000e+01
# 25%    1006.000000  2.400000e+02
# 50%    1011.000000  3.300000e+02
# 75%    1016.000000  5.000000e+02
# max    1022.000000  2.000000e+08

# %%
# The water_need average is still high. Remove any values outside
# a reasonable range. Say, 10000. 
df = df[df['water_need'] < 10000] 
df
# Out:
#       animal  uniq_id  water_need gender
# 0   elephant     1001       500.0      F
# 1   elephant     1002       600.0      F
# 2   elephant     1003       550.0      M
# 3      tiger     1004       300.0      M
# 4      tiger     1005       320.0      F
# 5      tiger     1006       330.0      F
# 6      tiger     1007       290.0      M
# 7      tiger     1008       310.0      F
# 9      zebra     1010       220.0      M
# 10     zebra     1011       240.0      F
# 11     zebra     1012       230.0      F
# 12     zebra     1013       220.0      F
# 14     zebra     1014       100.0      M
# 15     zebra     1015        80.0      M
# 16      lion     1016       420.0      F
# 17      lion     1017       600.0      F
# 18      lion     1018       500.0      F
# 19      lion     1019       390.0      M
# 21  kangaroo     1021       430.0      F
# 22  kangaroo     1022       410.0      M

# %%
# Now use describe and see if everything looks OK:
df.describe()
# Out:
#            uniq_id  water_need
# count    20.000000   20.000000
# mean   1011.200000  352.000000
# std       6.509911  150.633749
# min    1001.000000   80.000000
# 25%    1005.750000  237.500000
# 50%    1011.500000  325.000000
# 75%    1016.250000  447.500000
# max    1022.000000  600.000000

# %% [markdown]
#  # Great! Now the data is clean, we can continue...

# %%
# Get a list of all the animals
# Note that df['animal'] returns a Pandas Series, which has to be turned into a Python list
animals_series = df['animal']
animals_list = animals_series.tolist()
animals_list
# Out:
# ['elephant',
#  'elephant',
#  'elephant',
#  'tiger',
#  'tiger',
#  'tiger',
#  'tiger',
#  'tiger',
#  'zebra',
#  'zebra',
#  'zebra',
#  'zebra',
#  'zebra',
#  'zebra',
#  'lion',
#  'lion',
#  'lion',
#  'lion',
#  'kangaroo',
#  'kangaroo']

# %%
# Get a list of all the animals
# Note that df['animal'] returns a Pandas Series, which has to be turned into a Python list
# Note that df['animal'] is the same as df.animal
animals_series = df.animal
animals_list = animals_series.tolist()
animals_list
# Out:
# ['elephant',
#  'elephant',
#  'elephant',
#  'tiger',
#  'tiger',
#  'tiger',
#  'tiger',
#  'tiger',
#  'zebra',
#  'zebra',
#  'zebra',
#  'zebra',
#  'zebra',
#  'zebra',
#  'lion',
#  'lion',
#  'lion',
#  'lion',
#  'kangaroo',
#  'kangaroo']

# %%
# Note that df['animal'] returns a Pandas Series, which has to be turned into a Python list
# Note that df['animal'] is the same as df.animal
# Note you can shorten this to one line
animals_list = df.animal.tolist()
animals_list
# Out:
# ['elephant',
#  'elephant',
#  'elephant',
#  'tiger',
#  'tiger',
#  'tiger',
#  'tiger',
#  'tiger',
#  'zebra',
#  'zebra',
#  'zebra',
#  'zebra',
#  'zebra',
#  'zebra',
#  'lion',
#  'lion',
#  'lion',
#  'lion',
#  'kangaroo',
#  'kangaroo']

# %%
# Loop through the list of animals, print them each on a line
for animal in animals_list:
    print(animal)
# Out:
# elephant
# elephant
# elephant
# tiger
# tiger
# tiger
# tiger
# tiger
# zebra
# zebra
# zebra
# zebra
# zebra
# zebra
# lion
# lion
# lion
# lion
# kangaroo
# kangaroo

# %%
# Use the Pandas unique() function to get a list of unique animals.
df.animal.unique().tolist()
# Out:
# ['elephant', 'tiger', 'zebra', 'lion', 'kangaroo']

# %%
# Get the number of differnt animals. Use len()
len(df.animal.unique())
# Out:
# 5

# %%
# Get a count of gender
df[['gender','animal']].groupby('gender').count()
# Out:
#         animal
# gender
# F           12
# M            8

# %%
# Lets read in the CSV file and clean it
file = "Resources/zoo.csv"
df = pd.read_csv(file)
df = df.dropna()
df = df[df['water_need'] < 10000]

# %%
# Draw a bar chart!
df.plot(kind='bar',x='animal',y='water_need',color='blue')
#plt.rcParams['font.size'] = 14
#plt.rcParams['figure.figsize'] = (10,4)
plt.title("Animal Water Needs")
plt.ylabel("Water Needs")
plt.xlabel("Animals")

plt.show()
