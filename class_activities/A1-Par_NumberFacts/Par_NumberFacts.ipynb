# %%
# Dependencies
import requests
import json
import random

# %%
# Base URL for GET requests to retrieve number/date facts

# %%
# Ask the user what kind of data they would like to search for (Trivia, Math, or Year)

# %%
# Ask the user what number/year they would like a fact for, with the option to get a fact for a random number/year
