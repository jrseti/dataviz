# %%
import pandas as pd
pd.options.display.max_colwidth = 100

# %%
# load in Alice in Wonderland text
alice_file = '../Resources/alice.txt'

alice_df = pd.read_csv(alice_file, sep='\n', header=None)
alice_df.columns = ['text']
alice_df.head()
# Out:
#                                                                        text
# 0                                          ALICE’S ADVENTURES IN WONDERLAND
# 1                                           CHAPTER I. Down the Rabbit-Hole
# 2     Alice was beginning to get very tired of sitting by her sister on the
# 3  bank, and of having nothing to do: once or twice she had peeped into the
# 4   book her sister was reading, but it had no pictures or conversations in

# %%
# find all lines of text with the string 'cat'
p = # YOUR REGEX STRING HERE
alice_df[alice_df['text'].str.contains(p)]
# Out:
#                                                                           text
# 66         (Dinah was the cat.) ‘I hope they’ll remember her saucer of milk at
# 68     mice in the air, I’m afraid, but you might catch a bat, and that’s very
# 69     like a mouse, you know. But do cats eat bats, I wonder?’ And here Alice
# 71       sort of way, ‘Do cats eat bats? Do cats eat bats?’ and sometimes, ‘Do
# 72       bats eat cats?’ for, you see, as she couldn’t answer either question,
# 235    However, the Multiplication Table doesn’t signify: let’s try Geography.
# 312         the poor animal’s feelings. ‘I quite forgot you didn’t like cats.’
# 313    ‘Not like cats!’ cried the Mouse, in a shrill, passionate voice. ‘Would
# 314                                             YOU like cats if you were me?’
# 316     about it. And yet I wish I could show you our cat Dinah: I think you’d
# 317   take a fancy to cats if you could only see her. She is such a dear quiet
# 321        such a capital one for catching mice--oh, I beg your pardon!’ cried
# 327        cats: nasty, low, vulgar things! Don’t let me hear the name again!’
# 341    won’t talk about cats or dogs either, if you don’t like them!’ When the
# 345            history, and you’ll understand why it is I hate cats and dogs.’
# 366          sure she would catch a bad cold if she did not get dry very soon.
# 524       ‘Dinah’s our cat. And she’s such a capital one for catching mice you
# 535      cat in the world! Oh, my dear Dinah! I wonder if I shall ever see you
# 658        do well enough; don’t be particular--Here, Bill! catch hold of this
# 753       mushroom, and her eyes immediately met those of a large caterpillar,
# 1033  that did not sneeze, were the cook, and a large cat which was sitting on
# 1037                                                your cat grins like that?’
# 1038           ‘It’s a Cheshire cat,’ said the Duchess, ‘and that’s why. Pig!’
# 1042  ‘I didn’t know that Cheshire cats always grinned; in fact, I didn’t know
# 1043                                                    that cats COULD grin.’
# 1190  ‘Well! I’ve often seen a cat without a grin,’ thought Alice; ‘but a grin
# 1191        without a cat! It’s the most curious thing I ever saw in my life!’
# 1608     ‘A cat may look at a king,’ said Alice. ‘I’ve read that in some book,
# 1612                                                   have this cat removed!’
# 1825   ‘We had the best of educations--in fact, we went to school every day--’
# 1842                                 Distraction, Uglification, and Derision.’
# 1843   ‘I never heard of “Uglification,”’ Alice ventured to say. ‘What is it?’
# 2468   of the cattle in the distance would take the place of the Mock Turtle’s

# %%
# find all lines of text with the string 'cat' that begin with a space
p = # YOUR REGEX STRING HERE
alice_df[alice_df['text'].str.contains(p)]
# Out:
#                                                                           text
# 66         (Dinah was the cat.) ‘I hope they’ll remember her saucer of milk at
# 68     mice in the air, I’m afraid, but you might catch a bat, and that’s very
# 69     like a mouse, you know. But do cats eat bats, I wonder?’ And here Alice
# 71       sort of way, ‘Do cats eat bats? Do cats eat bats?’ and sometimes, ‘Do
# 72       bats eat cats?’ for, you see, as she couldn’t answer either question,
# 312         the poor animal’s feelings. ‘I quite forgot you didn’t like cats.’
# 313    ‘Not like cats!’ cried the Mouse, in a shrill, passionate voice. ‘Would
# 314                                             YOU like cats if you were me?’
# 316     about it. And yet I wish I could show you our cat Dinah: I think you’d
# 317   take a fancy to cats if you could only see her. She is such a dear quiet
# 321        such a capital one for catching mice--oh, I beg your pardon!’ cried
# 341    won’t talk about cats or dogs either, if you don’t like them!’ When the
# 345            history, and you’ll understand why it is I hate cats and dogs.’
# 366          sure she would catch a bad cold if she did not get dry very soon.
# 524       ‘Dinah’s our cat. And she’s such a capital one for catching mice you
# 658        do well enough; don’t be particular--Here, Bill! catch hold of this
# 753       mushroom, and her eyes immediately met those of a large caterpillar,
# 1033  that did not sneeze, were the cook, and a large cat which was sitting on
# 1037                                                your cat grins like that?’
# 1038           ‘It’s a Cheshire cat,’ said the Duchess, ‘and that’s why. Pig!’
# 1042  ‘I didn’t know that Cheshire cats always grinned; in fact, I didn’t know
# 1043                                                    that cats COULD grin.’
# 1190  ‘Well! I’ve often seen a cat without a grin,’ thought Alice; ‘but a grin
# 1191        without a cat! It’s the most curious thing I ever saw in my life!’
# 1608     ‘A cat may look at a king,’ said Alice. ‘I’ve read that in some book,
# 1612                                                   have this cat removed!’
# 2468   of the cattle in the distance would take the place of the Mock Turtle’s

# %%
# find all lines of text with the string 'cat' that begin with a space and end with a non-word character
p = # YOUR REGEX STRING HERE
alice_df[alice_df['text'].str.contains(p)]
# Out:
#                                                                           text
# 66         (Dinah was the cat.) ‘I hope they’ll remember her saucer of milk at
# 316     about it. And yet I wish I could show you our cat Dinah: I think you’d
# 524       ‘Dinah’s our cat. And she’s such a capital one for catching mice you
# 1033  that did not sneeze, were the cook, and a large cat which was sitting on
# 1037                                                your cat grins like that?’
# 1038           ‘It’s a Cheshire cat,’ said the Duchess, ‘and that’s why. Pig!’
# 1190  ‘Well! I’ve often seen a cat without a grin,’ thought Alice; ‘but a grin
# 1191        without a cat! It’s the most curious thing I ever saw in my life!’
# 1608     ‘A cat may look at a king,’ said Alice. ‘I’ve read that in some book,
# 1612                                                   have this cat removed!’
