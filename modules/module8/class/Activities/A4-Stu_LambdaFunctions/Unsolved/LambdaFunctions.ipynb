# %%
import pandas as pd

# %%
movies_df = pd.read_csv(f'../Resources/movies_metadata.csv')

movies_df = movies_df[movies_df['adult'] == 'False'].drop('adult',axis='columns')
movies_df['video'] = movies_df['video'] == 'True'
movies_df['budget'] = movies_df['budget'].astype(int)
movies_df['revenue'] = movies_df['revenue'].astype(float)
movies_df['id'] = pd.to_numeric(movies_df['id'], errors='raise')
movies_df['popularity'] = pd.to_numeric(movies_df['popularity'], errors='raise')
# Out:
# Z:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# The following cell uses a function `more_than_15_words` to select the rows from `movies_df` that have titles with more than 15 words. In the next cell, do the same selection, but using a lambda function

# %%
def more_than_15_words(title):
    split_title = title.split() # split the title into a list of words
    number_of_words_in_title = len(split_title) # count the number of words in the title
    is_greater_than_15 = number_of_words_in_title > 15 # check if the number of words is greater than 15
    return is_greater_than_15 # return whether or not the title has more than 15 words

movies_df[movies_df['original_title'].map(more_than_15_words)]
# Out:
#       belongs_to_collection   budget  \
# 7241                    NaN  5600000
# 7268                    NaN        0
# 8420                    NaN        0
# 9227                    NaN        0
# 14093                   NaN        0
# 36826                   NaN        0
# 38511                   NaN        0
# 38514                   NaN        0
# 38515                   NaN        0
# 44215                   NaN        0
#
#                                                   genres homepage      id  \
# 7241   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      NaN   10338
# 7268   [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...      NaN   65332
# 8420   [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN   22638
# 9227                                                  []      NaN   22616
# 14093  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN   36108
# 36826                [{'id': 99, 'name': 'Documentary'}]      NaN  270936
# 38511                [{'id': 99, 'name': 'Documentary'}]      NaN  132144
# 38514                [{'id': 99, 'name': 'Documentary'}]      NaN  132148
# 38515                [{'id': 99, 'name': 'Documentary'}]      NaN  132150
# 44215                  [{'id': 12, 'name': 'Adventure'}]      NaN   85854
#
#          imdb_id original_language  \
# 7241   tt0059797                en
# 7268   tt0070061                it
# 8420   tt0036910                en
# 9227   tt0230575                en
# 14093  tt0973844                en
# 36826  tt1023446                en
# 38511  tt0072685                es
# 38514  tt0074187                es
# 38515  tt0078831                es
# 44215  tt0052156                en
#
#                                           original_title  \
# 7241   Those Magnificent Men in Their Flying Machines...
# 7268   Film d'amore e d'anarchia, ovvero 'stamattina ...
# 8420   The Chronicle History of King Henry the Fifth ...
# 9227   Night of the Day of the Dawn of the Son of the...
# 14093  Chacun son cinema ou Ce petit coup au coeur qu...
# 36826  Ellen ten Damme: As I Was Wondering Where This...
# 38511  La batalla de Chile: La lucha de un pueblo sin...
# 38514  La batalla de Chile: La lucha de un pueblo sin...
# 38515  La batalla de Chile: La lucha de un pueblo sin...
# 44215  The Saga of the Viking Women and Their Voyage ...
#
#                                                 overview  popularity  ...  \
# 7241   Star studded comedy about a early 20th century...    5.191425  ...
# 7268   Set in Fascist Italy before the outbreak of Wo...    0.614959  ...
# 8420   Olivier mustered out of the navy to film this ...    1.200979  ...
# 9227   The makers of this parody of "Night of the Liv...    0.022568  ...
# 14093  A collective film of 33 shorts directed by dif...   10.604359  ...
# 36826  Documentary about Dutch artist Ellen ten Damme...    0.003571  ...
# 38511  Documents the rise of the right-wing movement ...    0.057128  ...
# 38514  Chronicles the events immediately surrounding ...    0.004351  ...
# 38515  Guzmán’s final instalment shifts from covering...    0.112442  ...
# 44215  A group of lonely Viking women build a ship an...    0.587937  ...
#
#       release_date     revenue runtime  \
# 7241    1965-06-03  29950000.0   138.0
# 7268    1973-02-23         0.0   120.0
# 8420    1944-11-24         0.0   137.0
# 9227    1991-01-01         0.0    96.0
# 14093   2007-05-19         0.0   100.0
# 36826   2007-04-19         0.0    66.0
# 38511   1975-03-18         0.0    97.0
# 38514   1976-03-13         0.0    88.0
# 38515   1979-03-15         0.0    78.0
# 44215   1957-12-01         0.0    66.0
#
#                                         spoken_languages    status  \
# 7241   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 7268           [{'iso_639_1': 'it', 'name': 'Italiano'}]  Released
# 8420   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 9227            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 14093  [{'iso_639_1': 'da', 'name': 'Dansk'}, {'iso_6...  Released
# 36826                                                 []  Released
# 38511           [{'iso_639_1': 'es', 'name': 'Español'}]  Released
# 38514           [{'iso_639_1': 'es', 'name': 'Español'}]  Released
# 38515           [{'iso_639_1': 'es', 'name': 'Español'}]  Released
# 44215           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 7241   or How I Flew from London to Paris in 25 hours...
# 7268                                                 NaN
# 8420                                                 NaN
# 9227                                                 NaN
# 14093                                                NaN
# 36826                                                NaN
# 38511                                                NaN
# 38514                                                NaN
# 38515                                                NaN
# 44215  Fabulous! Spectacular! Terrifying! The raw cou...
#
#                                                    title  video vote_average  \
# 7241   Those Magnificent Men in Their Flying Machines...  False          6.4
# 7268                                    Love and Anarchy  False          7.0
# 8420                                             Henry V  False          7.0
# 9227   Night of the Day of the Dawn of the Son of the...  False          5.3
# 14093                             To Each His Own Cinema  False          7.2
# 36826  Ellen ten Damme: As I Was Wondering Where This...  False          0.0
# 38511                       The Battle of Chile - Part I  False          6.3
# 38514                      The Battle of Chile - Part II  False          6.8
# 38515                     The Battle of Chile - Part III  False          6.0
# 44215  The Saga of the Viking Women and Their Voyage ...  False          2.0
#
#       vote_count
# 7241        40.0
# 7268         8.0
# 8420        25.0
# 9227         4.0
# 14093       26.0
# 36826        0.0
# 38511        4.0
# 38514        4.0
# 38515        3.0
# 44215        3.0
#
# [10 rows x 23 columns]

# %%
# Find all the movies that have more than 15 words in their title using a lambda function.
# YOUR CODE HERE
# Out:
#       belongs_to_collection   budget  \
# 7241                    NaN  5600000
# 7268                    NaN        0
# 8420                    NaN        0
# 9227                    NaN        0
# 14093                   NaN        0
# 36826                   NaN        0
# 38511                   NaN        0
# 38514                   NaN        0
# 38515                   NaN        0
# 44215                   NaN        0
#
#                                                   genres homepage      id  \
# 7241   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      NaN   10338
# 7268   [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...      NaN   65332
# 8420   [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN   22638
# 9227                                                  []      NaN   22616
# 14093  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN   36108
# 36826                [{'id': 99, 'name': 'Documentary'}]      NaN  270936
# 38511                [{'id': 99, 'name': 'Documentary'}]      NaN  132144
# 38514                [{'id': 99, 'name': 'Documentary'}]      NaN  132148
# 38515                [{'id': 99, 'name': 'Documentary'}]      NaN  132150
# 44215                  [{'id': 12, 'name': 'Adventure'}]      NaN   85854
#
#          imdb_id original_language  \
# 7241   tt0059797                en
# 7268   tt0070061                it
# 8420   tt0036910                en
# 9227   tt0230575                en
# 14093  tt0973844                en
# 36826  tt1023446                en
# 38511  tt0072685                es
# 38514  tt0074187                es
# 38515  tt0078831                es
# 44215  tt0052156                en
#
#                                           original_title  \
# 7241   Those Magnificent Men in Their Flying Machines...
# 7268   Film d'amore e d'anarchia, ovvero 'stamattina ...
# 8420   The Chronicle History of King Henry the Fifth ...
# 9227   Night of the Day of the Dawn of the Son of the...
# 14093  Chacun son cinema ou Ce petit coup au coeur qu...
# 36826  Ellen ten Damme: As I Was Wondering Where This...
# 38511  La batalla de Chile: La lucha de un pueblo sin...
# 38514  La batalla de Chile: La lucha de un pueblo sin...
# 38515  La batalla de Chile: La lucha de un pueblo sin...
# 44215  The Saga of the Viking Women and Their Voyage ...
#
#                                                 overview  popularity  ...  \
# 7241   Star studded comedy about a early 20th century...    5.191425  ...
# 7268   Set in Fascist Italy before the outbreak of Wo...    0.614959  ...
# 8420   Olivier mustered out of the navy to film this ...    1.200979  ...
# 9227   The makers of this parody of "Night of the Liv...    0.022568  ...
# 14093  A collective film of 33 shorts directed by dif...   10.604359  ...
# 36826  Documentary about Dutch artist Ellen ten Damme...    0.003571  ...
# 38511  Documents the rise of the right-wing movement ...    0.057128  ...
# 38514  Chronicles the events immediately surrounding ...    0.004351  ...
# 38515  Guzmán’s final instalment shifts from covering...    0.112442  ...
# 44215  A group of lonely Viking women build a ship an...    0.587937  ...
#
#       release_date     revenue runtime  \
# 7241    1965-06-03  29950000.0   138.0
# 7268    1973-02-23         0.0   120.0
# 8420    1944-11-24         0.0   137.0
# 9227    1991-01-01         0.0    96.0
# 14093   2007-05-19         0.0   100.0
# 36826   2007-04-19         0.0    66.0
# 38511   1975-03-18         0.0    97.0
# 38514   1976-03-13         0.0    88.0
# 38515   1979-03-15         0.0    78.0
# 44215   1957-12-01         0.0    66.0
#
#                                         spoken_languages    status  \
# 7241   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 7268           [{'iso_639_1': 'it', 'name': 'Italiano'}]  Released
# 8420   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 9227            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 14093  [{'iso_639_1': 'da', 'name': 'Dansk'}, {'iso_6...  Released
# 36826                                                 []  Released
# 38511           [{'iso_639_1': 'es', 'name': 'Español'}]  Released
# 38514           [{'iso_639_1': 'es', 'name': 'Español'}]  Released
# 38515           [{'iso_639_1': 'es', 'name': 'Español'}]  Released
# 44215           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 7241   or How I Flew from London to Paris in 25 hours...
# 7268                                                 NaN
# 8420                                                 NaN
# 9227                                                 NaN
# 14093                                                NaN
# 36826                                                NaN
# 38511                                                NaN
# 38514                                                NaN
# 38515                                                NaN
# 44215  Fabulous! Spectacular! Terrifying! The raw cou...
#
#                                                    title  video vote_average  \
# 7241   Those Magnificent Men in Their Flying Machines...  False          6.4
# 7268                                    Love and Anarchy  False          7.0
# 8420                                             Henry V  False          7.0
# 9227   Night of the Day of the Dawn of the Son of the...  False          5.3
# 14093                             To Each His Own Cinema  False          7.2
# 36826  Ellen ten Damme: As I Was Wondering Where This...  False          0.0
# 38511                       The Battle of Chile - Part I  False          6.3
# 38514                      The Battle of Chile - Part II  False          6.8
# 38515                     The Battle of Chile - Part III  False          6.0
# 44215  The Saga of the Viking Women and Their Voyage ...  False          2.0
#
#       vote_count
# 7241        40.0
# 7268         8.0
# 8420        25.0
# 9227         4.0
# 14093       26.0
# 36826        0.0
# 38511        4.0
# 38514        4.0
# 38515        3.0
# 44215        3.0
#
# [10 rows x 23 columns]

# %%
def hundredfold_return(row):
    revenue = row['revenue']
    budget = row['budget']
    budget_over_1000 = budget > 1000
    revenue_over_100x = revenue > 100 * budget
    return revenue_over_100x and budget_over_1000
    
movies_df[movies_df.apply(hundredfold_return, axis=1)]
# Out:
#                                    belongs_to_collection   budget  \
# 219    {'id': 182813, 'name': 'Clerks Collection', 'p...    27000
# 587                                                  NaN  1488423
# 893                                                  NaN  4000000
# 941    {'id': 261590, 'name': 'Living Dead Collection...   114000
# 1003                                                 NaN  3000000
# 1845   {'id': 1575, 'name': 'Rocky Collection', 'post...  1000000
# 1865   {'id': 9735, 'name': 'Friday the 13th Collecti...   550000
# 1873   {'id': 91361, 'name': 'Halloween Collection', ...   300000
# 1909   {'id': 87250, 'name': 'Bambi Collection', 'pos...   858000
# 2248                                                 NaN    12000
# 2346   {'id': 111751, 'name': 'Texas Chainsaw Massacr...    85000
# 2595   {'id': 64750, 'name': 'Blair Witch Collection'...    60000
# 3226                                                 NaN    24500
# 3245   {'id': 124950, 'name': 'American Graffiti Coll...   777000
# 3554                                                 NaN    10000
# 3580   {'id': 8945, 'name': 'Mad Max Collection', 'po...   400000
# 4316                                                 NaN   130000
# 5206                                                 NaN   106000
# 5340                                                 NaN   100000
# 5452   {'id': 267922, 'name': 'The Hills Have Eyes (O...   230000
# 6913                                                 NaN   100000
# 7121                                                 NaN    70000
# 7303                                                 NaN   850000
# 7733                                                 NaN   400000
# 7788   {'id': 475802, 'name': 'Super Size Me Collecti...    65000
# 8683                                                 NaN   150000
# 9461   {'id': 86113, 'name': 'Open Water Collection',...   130000
# 10660                                                NaN   169000
# 11347                                                NaN   100000
# 11826                                                NaN   160000
# 14192  {'id': 41437, 'name': 'Paranormal Activity Col...    15000
# 15898                                                NaN    30000
# 18338                                                NaN  1000000
# 31628                                                NaN   100000
# 41472                                                NaN     5000
# 42308                                                NaN   100000
#
#                                                   genres  \
# 219                       [{'id': 35, 'name': 'Comedy'}]
# 587    [{'id': 14, 'name': 'Fantasy'}, {'id': 16, 'na...
# 893    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 941                       [{'id': 27, 'name': 'Horror'}]
# 1003   [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 1845                       [{'id': 18, 'name': 'Drama'}]
# 1865                      [{'id': 27, 'name': 'Horror'}]
# 1873   [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 1909   [{'id': 16, 'name': 'Animation'}, {'id': 18, '...
# 2248   [{'id': 27, 'name': 'Horror'}, {'id': 35, 'nam...
# 2346                      [{'id': 27, 'name': 'Horror'}]
# 2595   [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 3226                      [{'id': 27, 'name': 'Horror'}]
# 3245   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 3554   [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...
# 3580   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4316   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 5206                       [{'id': 18, 'name': 'Drama'}]
# 5340   [{'id': 9648, 'name': 'Mystery'}, {'id': 27, '...
# 5452                      [{'id': 27, 'name': 'Horror'}]
# 6913   [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 7121   [{'id': 35, 'name': 'Comedy'}, {'id': 28, 'nam...
# 7303   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 7733                      [{'id': 35, 'name': 'Comedy'}]
# 7788   [{'id': 99, 'name': 'Documentary'}, {'id': 35,...
# 8683   [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 9461   [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 10660                     [{'id': 35, 'name': 'Comedy'}]
# 11347                      [{'id': 18, 'name': 'Drama'}]
# 11826  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 14192  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 15898                [{'id': 99, 'name': 'Documentary'}]
# 18338  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 31628  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 41472  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 42308  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...
#
#                                                 homepage      id    imdb_id  \
# 219                 http://www.miramax.com/movie/clerks/    2292  tt0109445
# 587    http://movies.disney.com/snow-white-and-the-se...     408  tt0029583
# 893                                                  NaN     770  tt0031381
# 941                                                  NaN   10331  tt0063350
# 1003                                                 NaN   12092  tt0043274
# 1845                                                 NaN    1366  tt0075148
# 1865                                                 NaN    4488  tt0080761
# 1873   http://www.theofficialjohncarpenter.com/hallow...     948  tt0077651
# 1909                      http://movies.disney.com/bambi    3170  tt0034492
# 2248                                                 NaN     692  tt0069089
# 2346                                                 NaN   30497  tt0072271
# 2595                          http://www.blairwitch.com/    2667  tt0185937
# 3226                                                 NaN   28172  tt0056875
# 3245                                                 NaN     838  tt0069704
# 3554                                                 NaN     985  tt0074486
# 3580                                                 NaN    9659  tt0079501
# 4316                                                 NaN    9462  tt0068935
# 5206                                                 NaN   46691  tt0065916
# 5340                                                 NaN    1842  tt0068837
# 5452                                                 NaN   12262  tt0077681
# 6913                                                 NaN     618  tt0004972
# 7121                                                 NaN   29473  tt0073282
# 7303                                                 NaN    9461  tt0070034
# 7733                                                 NaN    8193  tt0374900
# 7788                                                 NaN    9372  tt0390521
# 8683                 http://www.sonyclassics.com/badass/    5822  tt0067810
# 9461                                                 NaN      83  tt0374102
# 10660                                                NaN    9687  tt0444653
# 11347                    http://www.facingthegiants.com/   18925  tt0805526
# 11826                http://www.foxsearchlight.com/once/    5723  tt0907657
# 14192           http://www.paranormalactivity-movie.com/   23827  tt1179904
# 15898                    http://www.iamrogue.com/catfish   42296  tt1584016
# 18338                    http://www.devilinsidemovie.com   76487  tt1560985
# 31628                        http://thegallowsmovie.com/  299245  tt2309260
# 41472                                                NaN  363093  tt5066556
# 42308           https://a24films.com/films/a-ghost-story  428449  tt6265828
#
#       original_language                     original_title  \
# 219                  en                             Clerks
# 587                  en    Snow White and the Seven Dwarfs
# 893                  en                 Gone with the Wind
# 941                  en           Night of the Living Dead
# 1003                 en                Alice in Wonderland
# 1845                 en                              Rocky
# 1865                 en                    Friday the 13th
# 1873                 en                          Halloween
# 1909                 en                              Bambi
# 2248                 en                     Pink Flamingos
# 2346                 en       The Texas Chain Saw Massacre
# 2595                 en            The Blair Witch Project
# 3226                 en                        Blood Feast
# 3245                 en                  American Graffiti
# 3554                 en                         Eraserhead
# 3580                 en                            Mad Max
# 4316                 cn                               猛龍過江
# 5206                 en                                Joe
# 5340                 en          The Legend of Boggy Creek
# 5452                 en                The Hills Have Eyes
# 6913                 en              The Birth of a Nation
# 7121                 en                  Let's Do It Again
# 7303                 en                   Enter the Dragon
# 7733                 en                  Napoleon Dynamite
# 7788                 en                      Super Size Me
# 8683                 en  Sweet Sweetback's Baadasssss Song
# 9461                 en                         Open Water
# 10660                en                        Keeping Mum
# 11347                en                  Facing the Giants
# 11826                en                               Once
# 14192                en                Paranormal Activity
# 15898                en                            Catfish
# 18338                en                   The Devil Inside
# 31628                en                        The Gallows
# 41472                ko                                 대호
# 42308                en                      A Ghost Story
#
#                                                 overview  popularity  ...  \
# 219    Convenience and video store clerks Dante and R...   10.513367  ...
# 587    A beautiful girl, Snow White, takes refuge in ...   16.263878  ...
# 893    An American classic in which a manipulative wo...   14.240357  ...
# 941    A group of people try to survive an attack of ...   14.384198  ...
# 1003   On a golden afternoon, young Alice follows a W...   16.488937  ...
# 1845   When world heavyweight boxing champion, Apollo...   14.774066  ...
# 1865   Camp counselors are stalked and murdered by an...   12.146747  ...
# 1873   In John Carpenter's horror classic, a psychoti...   13.672759  ...
# 1909   Bambi's tale unfolds from season to season as ...   13.698132  ...
# 2248   Notorious Baltimore criminal and underground f...    5.738871  ...
# 2346   Five friends visiting their grandfather's hous...   15.526413  ...
# 2595   In October of 1994 three student filmmakers di...   14.838386  ...
# 3226   In the sleepy suburbs of Miami, seemingly norm...    1.783412  ...
# 3245   A couple of high school graduates spend one fi...    9.188584  ...
# 3554   Henry Spencer tries to survive his industrial ...    7.871001  ...
# 3580   In a dystopian future Australia, a vicious bik...   11.412619  ...
# 4316   Tang Lung arrives in Rome to help his cousins ...   11.116474  ...
# 5206   Bill, a wealthy businessman, confronts his jun...    0.345862  ...
# 5340   A documentary-style drama based on true accoun...    1.522753  ...
# 5452   On the way to California, a family has the mis...    4.788002  ...
# 6913   The Birth of A Nation is a silent film from 19...    5.113205  ...
# 7121   Clyde Williams and Billy Foster are a couple o...    1.411831  ...
# 7303   A martial artist agrees to spy on a reclusive ...   10.687757  ...
# 7733   A listless and alienated teenager decides to h...   10.287419  ...
# 7788   Morgan Spurlock subjects himself to a diet bas...    5.266103  ...
# 8683   After saving a Black Panther from some racist ...    1.435148  ...
# 9461   Two divers are left out at sea without a boat....   10.652818  ...
# 10660  A pastor preoccupied with writing the perfect ...    5.742659  ...
# 11347  A losing coach with an underdog football team ...    7.485908  ...
# 11826  A vacuum repairman moonlights as a street musi...   10.357064  ...
# 14192  After a young, middle class couple moves into ...   12.706424  ...
# 15898  Nev, a 24-year-old New York-based photographer...    5.174738  ...
# 18338  In Italy, a woman becomes involved in a series...    5.747675  ...
# 31628  20 years after a horrific accident during a sm...    7.515050  ...
# 41472  While the Kingdom of Korea is under occupation...    3.447894  ...
# 42308  Recently deceased, a white-sheeted ghost retur...   24.339781  ...
#
#       release_date      revenue runtime  \
# 219     1994-09-13    3151130.0    92.0
# 587     1937-12-20  184925486.0    83.0
# 893     1939-12-15  400176459.0   238.0
# 941     1968-10-01   30000000.0    96.0
# 1003    1951-07-03  572000000.0    75.0
# 1845    1976-11-21  117235147.0   119.0
# 1865    1980-05-09   59754601.0    95.0
# 1873    1978-10-25   70000000.0    91.0
# 1909    1942-08-14  267447150.0    70.0
# 2248    1972-03-12    6000000.0    93.0
# 2346    1974-10-01   30859000.0    83.0
# 2595    1999-07-14  248000000.0    81.0
# 3226    1963-06-06    4000000.0    67.0
# 3245    1973-08-01  140000000.0   110.0
# 3554    1977-03-19    7000000.0    89.0
# 3580    1979-04-12  100000000.0    93.0
# 4316    1972-06-01   85000000.0   100.0
# 5206    1970-07-15   19319254.0   107.0
# 5340    1972-08-01   22000000.0    90.0
# 5452    1977-07-22   25000000.0    89.0
# 6913    1915-02-08   11000000.0   193.0
# 7121    1975-10-11   11800000.0   110.0
# 7303    1973-08-17   90000000.0    99.0
# 7733    2004-06-11   46118097.0    95.0
# 7788    2004-01-17   28575078.0   100.0
# 8683    1971-04-23   15200000.0    97.0
# 9461    2004-08-06   54667954.0    79.0
# 10660   2005-12-02   18564702.0   103.0
# 11347   2006-09-29   10178331.0   111.0
# 11826   2007-03-23   20710513.0    85.0
# 14192   2007-09-14  193355800.0    86.0
# 15898   2010-09-17    3045943.0    87.0
# 18338   2012-01-06  101758490.0    83.0
# 31628   2015-07-10   42664410.0    87.0
# 41472   2015-12-16   11083449.0   139.0
# 42308   2017-07-07   15584255.0    92.0
#
#                                         spoken_languages    status  \
# 219             [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 587             [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 893             [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 941             [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1003            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1845            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1865            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1873            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1909            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2248            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2346            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2595            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3226            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3245            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3554            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3580            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4316   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 5206            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 5340            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 5452            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 6913        [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# 7121            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 7303   [{'iso_639_1': 'cn', 'name': '广州话 / 廣州話'}, {'i...  Released
# 7733            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 7788            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 8683            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 9461            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 10660           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 11347           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 11826           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 14192           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 15898           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 18338           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 31628           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 41472  [{'iso_639_1': 'ja', 'name': '日本語'}, {'iso_639...  Released
# 42308           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 219    Just because they serve you doesn't mean they ...
# 587    The Happiest, Dopiest, Grumpiest, Sneeziest mo...
# 893                    The greatest romance of all time!
# 941        If it doesn't scare you, you're already dead!
# 1003             A world of wonders in One Great Picture
# 1845           His whole life was a million-to-one shot.
# 1865   They were warned...They are doomed...And on Fr...
# 1873                              The Night He Came Home
# 1909                                 A great love story.
# 2248                          An exercise in poor taste.
# 2346     Who will survive and what will be left of them?
# 2595     The scariest movie of all time is a true story.
# 3226   You'll Recoil and Shudder as You Witness the S...
# 3245                              Where were you in '62?
# 3554                        Where your nightmares end...
# 3580                     The Maximum Force Of The Future
# 4316   The Colosseum . . the battleground of Bruce Le...
# 5206                              Keep America Beautiful
# 5340                                       A True Story.
# 5452   A nice American family. They didn't want to ki...
# 6913                The fiery cross of the Ku Klux Klan.
# 7121   It's the same two dudes from "Uptown Saturday ...
# 7303   Their deadly mission: to crack the forbidden i...
# 7733        He's out to prove he's got nothing to prove.
# 7788   The first ever reality-based movie ... everyth...
# 8683      The Film that THE MAN doesn't want you to see!
# 9461                                Scream all you want.
# 10660        Some family secrets are best kept...buried.
# 11347  Never give up. Never back down. Never lose faith.
# 11826            How often do you find the right person?
# 14192                       What Happens When You Sleep?
# 15898              Don't let anyone tell you what it is.
# 18338                                   No soul is safe.
# 31628                        Every School Has Its Spirit
# 41472                                                NaN
# 42308                                It's all about time
#
#                                    title  video vote_average vote_count
# 219                               Clerks  False          7.4      769.0
# 587      Snow White and the Seven Dwarfs  False          6.9     1973.0
# 893                   Gone with the Wind  False          7.7      995.0
# 941             Night of the Living Dead  False          7.5      591.0
# 1003                 Alice in Wonderland  False          7.0     1557.0
# 1845                               Rocky  False          7.5     1843.0
# 1865                     Friday the 13th  False          6.4      622.0
# 1873                           Halloween  False          7.4     1066.0
# 1909                               Bambi  False          6.8     1450.0
# 2248                      Pink Flamingos  False          6.2      111.0
# 2346        The Texas Chain Saw Massacre  False          7.1      617.0
# 2595             The Blair Witch Project  False          6.3     1090.0
# 3226                         Blood Feast  False          5.3       26.0
# 3245                   American Graffiti  False          6.9      330.0
# 3554                          Eraserhead  False          7.5      500.0
# 3580                             Mad Max  False          6.6     1235.0
# 4316               The Way of the Dragon  False          7.4      235.0
# 5206                                 Joe  False          5.4        9.0
# 5340           The Legend of Boggy Creek  False          5.6       19.0
# 5452                 The Hills Have Eyes  False          6.1      145.0
# 6913               The Birth of a Nation  False          6.4      109.0
# 7121                   Let's Do It Again  False          7.7       10.0
# 7303                    Enter the Dragon  False          7.3      489.0
# 7733                   Napoleon Dynamite  False          6.7      567.0
# 7788                       Super Size Me  False          6.6      520.0
# 8683   Sweet Sweetback's Baadasssss Song  False          4.7       19.0
# 9461                          Open Water  False          5.3      320.0
# 10660                        Keeping Mum  False          6.5      165.0
# 11347                  Facing the Giants  False          6.6       64.0
# 11826                               Once  False          7.4      457.0
# 14192                Paranormal Activity  False          5.9     1351.0
# 15898                            Catfish  False          6.5      201.0
# 18338                   The Devil Inside  False          4.6      263.0
# 31628                        The Gallows  False          4.9      370.0
# 41472    The Tiger: An Old Hunter's Tale  False          7.5       17.0
# 42308                      A Ghost Story  False          6.8       95.0
#
# [36 rows x 23 columns]

# %%
# Find all movies with budgets over 1000 that pulled in revenue over 100x their budget using a lambda function
# YOUR CODE HERE
# Out:
#                                    belongs_to_collection   budget  \
# 219    {'id': 182813, 'name': 'Clerks Collection', 'p...    27000
# 587                                                  NaN  1488423
# 893                                                  NaN  4000000
# 941    {'id': 261590, 'name': 'Living Dead Collection...   114000
# 1003                                                 NaN  3000000
# 1845   {'id': 1575, 'name': 'Rocky Collection', 'post...  1000000
# 1865   {'id': 9735, 'name': 'Friday the 13th Collecti...   550000
# 1873   {'id': 91361, 'name': 'Halloween Collection', ...   300000
# 1909   {'id': 87250, 'name': 'Bambi Collection', 'pos...   858000
# 2248                                                 NaN    12000
# 2346   {'id': 111751, 'name': 'Texas Chainsaw Massacr...    85000
# 2595   {'id': 64750, 'name': 'Blair Witch Collection'...    60000
# 3226                                                 NaN    24500
# 3245   {'id': 124950, 'name': 'American Graffiti Coll...   777000
# 3554                                                 NaN    10000
# 3580   {'id': 8945, 'name': 'Mad Max Collection', 'po...   400000
# 4316                                                 NaN   130000
# 5206                                                 NaN   106000
# 5340                                                 NaN   100000
# 5452   {'id': 267922, 'name': 'The Hills Have Eyes (O...   230000
# 6913                                                 NaN   100000
# 7121                                                 NaN    70000
# 7303                                                 NaN   850000
# 7733                                                 NaN   400000
# 7788   {'id': 475802, 'name': 'Super Size Me Collecti...    65000
# 8683                                                 NaN   150000
# 9461   {'id': 86113, 'name': 'Open Water Collection',...   130000
# 10660                                                NaN   169000
# 11347                                                NaN   100000
# 11826                                                NaN   160000
# 14192  {'id': 41437, 'name': 'Paranormal Activity Col...    15000
# 15898                                                NaN    30000
# 18338                                                NaN  1000000
# 31628                                                NaN   100000
# 41472                                                NaN     5000
# 42308                                                NaN   100000
#
#                                                   genres  \
# 219                       [{'id': 35, 'name': 'Comedy'}]
# 587    [{'id': 14, 'name': 'Fantasy'}, {'id': 16, 'na...
# 893    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 941                       [{'id': 27, 'name': 'Horror'}]
# 1003   [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 1845                       [{'id': 18, 'name': 'Drama'}]
# 1865                      [{'id': 27, 'name': 'Horror'}]
# 1873   [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 1909   [{'id': 16, 'name': 'Animation'}, {'id': 18, '...
# 2248   [{'id': 27, 'name': 'Horror'}, {'id': 35, 'nam...
# 2346                      [{'id': 27, 'name': 'Horror'}]
# 2595   [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 3226                      [{'id': 27, 'name': 'Horror'}]
# 3245   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 3554   [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...
# 3580   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4316   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 5206                       [{'id': 18, 'name': 'Drama'}]
# 5340   [{'id': 9648, 'name': 'Mystery'}, {'id': 27, '...
# 5452                      [{'id': 27, 'name': 'Horror'}]
# 6913   [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 7121   [{'id': 35, 'name': 'Comedy'}, {'id': 28, 'nam...
# 7303   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 7733                      [{'id': 35, 'name': 'Comedy'}]
# 7788   [{'id': 99, 'name': 'Documentary'}, {'id': 35,...
# 8683   [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 9461   [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 10660                     [{'id': 35, 'name': 'Comedy'}]
# 11347                      [{'id': 18, 'name': 'Drama'}]
# 11826  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 14192  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 15898                [{'id': 99, 'name': 'Documentary'}]
# 18338  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 31628  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 41472  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 42308  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...
#
#                                                 homepage      id    imdb_id  \
# 219                 http://www.miramax.com/movie/clerks/    2292  tt0109445
# 587    http://movies.disney.com/snow-white-and-the-se...     408  tt0029583
# 893                                                  NaN     770  tt0031381
# 941                                                  NaN   10331  tt0063350
# 1003                                                 NaN   12092  tt0043274
# 1845                                                 NaN    1366  tt0075148
# 1865                                                 NaN    4488  tt0080761
# 1873   http://www.theofficialjohncarpenter.com/hallow...     948  tt0077651
# 1909                      http://movies.disney.com/bambi    3170  tt0034492
# 2248                                                 NaN     692  tt0069089
# 2346                                                 NaN   30497  tt0072271
# 2595                          http://www.blairwitch.com/    2667  tt0185937
# 3226                                                 NaN   28172  tt0056875
# 3245                                                 NaN     838  tt0069704
# 3554                                                 NaN     985  tt0074486
# 3580                                                 NaN    9659  tt0079501
# 4316                                                 NaN    9462  tt0068935
# 5206                                                 NaN   46691  tt0065916
# 5340                                                 NaN    1842  tt0068837
# 5452                                                 NaN   12262  tt0077681
# 6913                                                 NaN     618  tt0004972
# 7121                                                 NaN   29473  tt0073282
# 7303                                                 NaN    9461  tt0070034
# 7733                                                 NaN    8193  tt0374900
# 7788                                                 NaN    9372  tt0390521
# 8683                 http://www.sonyclassics.com/badass/    5822  tt0067810
# 9461                                                 NaN      83  tt0374102
# 10660                                                NaN    9687  tt0444653
# 11347                    http://www.facingthegiants.com/   18925  tt0805526
# 11826                http://www.foxsearchlight.com/once/    5723  tt0907657
# 14192           http://www.paranormalactivity-movie.com/   23827  tt1179904
# 15898                    http://www.iamrogue.com/catfish   42296  tt1584016
# 18338                    http://www.devilinsidemovie.com   76487  tt1560985
# 31628                        http://thegallowsmovie.com/  299245  tt2309260
# 41472                                                NaN  363093  tt5066556
# 42308           https://a24films.com/films/a-ghost-story  428449  tt6265828
#
#       original_language                     original_title  \
# 219                  en                             Clerks
# 587                  en    Snow White and the Seven Dwarfs
# 893                  en                 Gone with the Wind
# 941                  en           Night of the Living Dead
# 1003                 en                Alice in Wonderland
# 1845                 en                              Rocky
# 1865                 en                    Friday the 13th
# 1873                 en                          Halloween
# 1909                 en                              Bambi
# 2248                 en                     Pink Flamingos
# 2346                 en       The Texas Chain Saw Massacre
# 2595                 en            The Blair Witch Project
# 3226                 en                        Blood Feast
# 3245                 en                  American Graffiti
# 3554                 en                         Eraserhead
# 3580                 en                            Mad Max
# 4316                 cn                               猛龍過江
# 5206                 en                                Joe
# 5340                 en          The Legend of Boggy Creek
# 5452                 en                The Hills Have Eyes
# 6913                 en              The Birth of a Nation
# 7121                 en                  Let's Do It Again
# 7303                 en                   Enter the Dragon
# 7733                 en                  Napoleon Dynamite
# 7788                 en                      Super Size Me
# 8683                 en  Sweet Sweetback's Baadasssss Song
# 9461                 en                         Open Water
# 10660                en                        Keeping Mum
# 11347                en                  Facing the Giants
# 11826                en                               Once
# 14192                en                Paranormal Activity
# 15898                en                            Catfish
# 18338                en                   The Devil Inside
# 31628                en                        The Gallows
# 41472                ko                                 대호
# 42308                en                      A Ghost Story
#
#                                                 overview  popularity  ...  \
# 219    Convenience and video store clerks Dante and R...   10.513367  ...
# 587    A beautiful girl, Snow White, takes refuge in ...   16.263878  ...
# 893    An American classic in which a manipulative wo...   14.240357  ...
# 941    A group of people try to survive an attack of ...   14.384198  ...
# 1003   On a golden afternoon, young Alice follows a W...   16.488937  ...
# 1845   When world heavyweight boxing champion, Apollo...   14.774066  ...
# 1865   Camp counselors are stalked and murdered by an...   12.146747  ...
# 1873   In John Carpenter's horror classic, a psychoti...   13.672759  ...
# 1909   Bambi's tale unfolds from season to season as ...   13.698132  ...
# 2248   Notorious Baltimore criminal and underground f...    5.738871  ...
# 2346   Five friends visiting their grandfather's hous...   15.526413  ...
# 2595   In October of 1994 three student filmmakers di...   14.838386  ...
# 3226   In the sleepy suburbs of Miami, seemingly norm...    1.783412  ...
# 3245   A couple of high school graduates spend one fi...    9.188584  ...
# 3554   Henry Spencer tries to survive his industrial ...    7.871001  ...
# 3580   In a dystopian future Australia, a vicious bik...   11.412619  ...
# 4316   Tang Lung arrives in Rome to help his cousins ...   11.116474  ...
# 5206   Bill, a wealthy businessman, confronts his jun...    0.345862  ...
# 5340   A documentary-style drama based on true accoun...    1.522753  ...
# 5452   On the way to California, a family has the mis...    4.788002  ...
# 6913   The Birth of A Nation is a silent film from 19...    5.113205  ...
# 7121   Clyde Williams and Billy Foster are a couple o...    1.411831  ...
# 7303   A martial artist agrees to spy on a reclusive ...   10.687757  ...
# 7733   A listless and alienated teenager decides to h...   10.287419  ...
# 7788   Morgan Spurlock subjects himself to a diet bas...    5.266103  ...
# 8683   After saving a Black Panther from some racist ...    1.435148  ...
# 9461   Two divers are left out at sea without a boat....   10.652818  ...
# 10660  A pastor preoccupied with writing the perfect ...    5.742659  ...
# 11347  A losing coach with an underdog football team ...    7.485908  ...
# 11826  A vacuum repairman moonlights as a street musi...   10.357064  ...
# 14192  After a young, middle class couple moves into ...   12.706424  ...
# 15898  Nev, a 24-year-old New York-based photographer...    5.174738  ...
# 18338  In Italy, a woman becomes involved in a series...    5.747675  ...
# 31628  20 years after a horrific accident during a sm...    7.515050  ...
# 41472  While the Kingdom of Korea is under occupation...    3.447894  ...
# 42308  Recently deceased, a white-sheeted ghost retur...   24.339781  ...
#
#       release_date      revenue runtime  \
# 219     1994-09-13    3151130.0    92.0
# 587     1937-12-20  184925486.0    83.0
# 893     1939-12-15  400176459.0   238.0
# 941     1968-10-01   30000000.0    96.0
# 1003    1951-07-03  572000000.0    75.0
# 1845    1976-11-21  117235147.0   119.0
# 1865    1980-05-09   59754601.0    95.0
# 1873    1978-10-25   70000000.0    91.0
# 1909    1942-08-14  267447150.0    70.0
# 2248    1972-03-12    6000000.0    93.0
# 2346    1974-10-01   30859000.0    83.0
# 2595    1999-07-14  248000000.0    81.0
# 3226    1963-06-06    4000000.0    67.0
# 3245    1973-08-01  140000000.0   110.0
# 3554    1977-03-19    7000000.0    89.0
# 3580    1979-04-12  100000000.0    93.0
# 4316    1972-06-01   85000000.0   100.0
# 5206    1970-07-15   19319254.0   107.0
# 5340    1972-08-01   22000000.0    90.0
# 5452    1977-07-22   25000000.0    89.0
# 6913    1915-02-08   11000000.0   193.0
# 7121    1975-10-11   11800000.0   110.0
# 7303    1973-08-17   90000000.0    99.0
# 7733    2004-06-11   46118097.0    95.0
# 7788    2004-01-17   28575078.0   100.0
# 8683    1971-04-23   15200000.0    97.0
# 9461    2004-08-06   54667954.0    79.0
# 10660   2005-12-02   18564702.0   103.0
# 11347   2006-09-29   10178331.0   111.0
# 11826   2007-03-23   20710513.0    85.0
# 14192   2007-09-14  193355800.0    86.0
# 15898   2010-09-17    3045943.0    87.0
# 18338   2012-01-06  101758490.0    83.0
# 31628   2015-07-10   42664410.0    87.0
# 41472   2015-12-16   11083449.0   139.0
# 42308   2017-07-07   15584255.0    92.0
#
#                                         spoken_languages    status  \
# 219             [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 587             [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 893             [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 941             [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1003            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1845            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1865            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1873            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1909            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2248            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2346            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2595            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3226            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3245            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3554            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3580            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4316   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 5206            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 5340            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 5452            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 6913        [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# 7121            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 7303   [{'iso_639_1': 'cn', 'name': '广州话 / 廣州話'}, {'i...  Released
# 7733            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 7788            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 8683            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 9461            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 10660           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 11347           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 11826           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 14192           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 15898           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 18338           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 31628           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 41472  [{'iso_639_1': 'ja', 'name': '日本語'}, {'iso_639...  Released
# 42308           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 219    Just because they serve you doesn't mean they ...
# 587    The Happiest, Dopiest, Grumpiest, Sneeziest mo...
# 893                    The greatest romance of all time!
# 941        If it doesn't scare you, you're already dead!
# 1003             A world of wonders in One Great Picture
# 1845           His whole life was a million-to-one shot.
# 1865   They were warned...They are doomed...And on Fr...
# 1873                              The Night He Came Home
# 1909                                 A great love story.
# 2248                          An exercise in poor taste.
# 2346     Who will survive and what will be left of them?
# 2595     The scariest movie of all time is a true story.
# 3226   You'll Recoil and Shudder as You Witness the S...
# 3245                              Where were you in '62?
# 3554                        Where your nightmares end...
# 3580                     The Maximum Force Of The Future
# 4316   The Colosseum . . the battleground of Bruce Le...
# 5206                              Keep America Beautiful
# 5340                                       A True Story.
# 5452   A nice American family. They didn't want to ki...
# 6913                The fiery cross of the Ku Klux Klan.
# 7121   It's the same two dudes from "Uptown Saturday ...
# 7303   Their deadly mission: to crack the forbidden i...
# 7733        He's out to prove he's got nothing to prove.
# 7788   The first ever reality-based movie ... everyth...
# 8683      The Film that THE MAN doesn't want you to see!
# 9461                                Scream all you want.
# 10660        Some family secrets are best kept...buried.
# 11347  Never give up. Never back down. Never lose faith.
# 11826            How often do you find the right person?
# 14192                       What Happens When You Sleep?
# 15898              Don't let anyone tell you what it is.
# 18338                                   No soul is safe.
# 31628                        Every School Has Its Spirit
# 41472                                                NaN
# 42308                                It's all about time
#
#                                    title  video vote_average vote_count
# 219                               Clerks  False          7.4      769.0
# 587      Snow White and the Seven Dwarfs  False          6.9     1973.0
# 893                   Gone with the Wind  False          7.7      995.0
# 941             Night of the Living Dead  False          7.5      591.0
# 1003                 Alice in Wonderland  False          7.0     1557.0
# 1845                               Rocky  False          7.5     1843.0
# 1865                     Friday the 13th  False          6.4      622.0
# 1873                           Halloween  False          7.4     1066.0
# 1909                               Bambi  False          6.8     1450.0
# 2248                      Pink Flamingos  False          6.2      111.0
# 2346        The Texas Chain Saw Massacre  False          7.1      617.0
# 2595             The Blair Witch Project  False          6.3     1090.0
# 3226                         Blood Feast  False          5.3       26.0
# 3245                   American Graffiti  False          6.9      330.0
# 3554                          Eraserhead  False          7.5      500.0
# 3580                             Mad Max  False          6.6     1235.0
# 4316               The Way of the Dragon  False          7.4      235.0
# 5206                                 Joe  False          5.4        9.0
# 5340           The Legend of Boggy Creek  False          5.6       19.0
# 5452                 The Hills Have Eyes  False          6.1      145.0
# 6913               The Birth of a Nation  False          6.4      109.0
# 7121                   Let's Do It Again  False          7.7       10.0
# 7303                    Enter the Dragon  False          7.3      489.0
# 7733                   Napoleon Dynamite  False          6.7      567.0
# 7788                       Super Size Me  False          6.6      520.0
# 8683   Sweet Sweetback's Baadasssss Song  False          4.7       19.0
# 9461                          Open Water  False          5.3      320.0
# 10660                        Keeping Mum  False          6.5      165.0
# 11347                  Facing the Giants  False          6.6       64.0
# 11826                               Once  False          7.4      457.0
# 14192                Paranormal Activity  False          5.9     1351.0
# 15898                            Catfish  False          6.5      201.0
# 18338                   The Devil Inside  False          4.6      263.0
# 31628                        The Gallows  False          4.9      370.0
# 41472    The Tiger: An Old Hunter's Tale  False          7.5       17.0
# 42308                      A Ghost Story  False          6.8       95.0
#
# [36 rows x 23 columns]

# %%
# load in list of English words
words_file = '../Resources/words.txt'

words_df = pd.read_csv(words_file, sep='\n', header=None)
words_df.columns = ['text']
words_df.head()
# Out:
#   text
# 0  the
# 1   of
# 2  and
# 3   to
# 4    a

# %%
def contains_x(word):
    split_word = list(word)
    word_contains_x = 'x' in split_word
    return word_contains_x

words_df[words_df['text'].map(contains_x)]
# Out:
#               text
# 97               x
# 120           next
# 274          index
# 347           text
# 449            box
# ...            ...
# 9748       expects
# 9759  examinations
# 9791       halifax
# 9808      examines
# 9872      lightbox
#
# [246 rows x 1 columns]

# %%
# Find all words containing the letter 'x' using a lambda function
# YOUR CODE HERE
# Out:
#               text
# 97               x
# 120           next
# 274          index
# 347           text
# 449            box
# ...            ...
# 9748       expects
# 9759  examinations
# 9791       halifax
# 9808      examines
# 9872      lightbox
#
# [246 rows x 1 columns]
