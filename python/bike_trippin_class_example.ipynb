# %%
# This was an example we had in class on Oct 20, 2020
# There was an error in the provided example, the pie
# chart would not draw. I corrected this issue and will
# review in class, examining the error nmessage to figure
# out the root of the problem.
# I left the error in place and will demonstrate the correction in class.

# %%
# %matplotlib inline

# %%
# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Import our data into pandas from CSV
string_thing = 'Resources/trip.csv'
bike_trips_df = pd.read_csv(string_thing, low_memory=False)

bike_trips_df
# Out:
#                 stoptime    bikeid  tripduration  \
# 0       10/13/2014 10:48  SEA00298       985.935
# 1       10/13/2014 10:48  SEA00195       926.375
# 2       10/13/2014 10:48  SEA00486       883.831
# 3       10/13/2014 10:48  SEA00333       865.937
# 4       10/13/2014 10:49  SEA00202       923.923
# ...                  ...       ...           ...
# 286853   8/31/2016 23:45  SEA00201       679.532
# 286854     9/1/2016 0:20  SEA00247      1965.418
# 286855     9/1/2016 0:20  SEA00300      1951.173
# 286856     9/1/2016 0:20  SEA00047      1883.299
# 286857     9/1/2016 0:20  SEA00442      1896.031
#
#                              from_station_name  \
# 0                          2nd Ave & Spring St
# 1                          2nd Ave & Spring St
# 2                          2nd Ave & Spring St
# 3                          2nd Ave & Spring St
# 4                          2nd Ave & Spring St
# ...                                        ...
# 286853                 Harvard Ave & E Pine St
# 286854  Cal Anderson Park / 11th Ave & Pine St
# 286855  Cal Anderson Park / 11th Ave & Pine St
# 286856  Cal Anderson Park / 11th Ave & Pine St
# 286857  Cal Anderson Park / 11th Ave & Pine St
#
#                                           to_station_name from_station_id  \
# 0       Occidental Park / Occidental Ave S & S Washing...          CBD-06
# 1       Occidental Park / Occidental Ave S & S Washing...          CBD-06
# 2       Occidental Park / Occidental Ave S & S Washing...          CBD-06
# 3       Occidental Park / Occidental Ave S & S Washing...          CBD-06
# 4       Occidental Park / Occidental Ave S & S Washing...          CBD-06
# ...                                                   ...             ...
# 286853                                2nd Ave & Spring St           CH-09
# 286854                              6th Ave S & S King St           CH-08
# 286855                              6th Ave S & S King St           CH-08
# 286856                              6th Ave S & S King St           CH-08
# 286857                              6th Ave S & S King St           CH-08
#
#        to_station_id                usertype  gender birthyear
# 0              PS-04                  Member    Male      1960
# 1              PS-04                  Member    Male      1970
# 2              PS-04                  Member  Female      1988
# 3              PS-04                  Member  Female      1977
# 4              PS-04                  Member    Male      1971
# ...              ...                     ...     ...       ...
# 286853        CBD-06  Short-Term Pass Holder     NaN       NaN
# 286854         ID-04  Short-Term Pass Holder     NaN       NaN
# 286855         ID-04  Short-Term Pass Holder     NaN       NaN
# 286856         ID-04  Short-Term Pass Holder     NaN       NaN
# 286857         ID-04  Short-Term Pass Holder     NaN       NaN
#
# [286858 rows x 10 columns]

# %%
# Split up our data into groups based upon 'gender'
gender_groups = bike_trips_df.groupby('gender')

# Find out how many of each gender took bike trips
gender_trips = gender_groups['tripduration'].count()

# Drop the 'stoptime' row that is contained within our group
gender_trips = gender_trips.drop(gender_trips.index[3])

# Chart our data, give it a title, and label the axes
gender_chart = gender_trips.plot(kind="bar", title="Bike Trips by Gender")
gender_chart.set_xlabel("Gender")
gender_chart.set_ylabel("Number of Trips Taken")

plt.tight_layout()
plt.show()

# %%
# Split up our data into groups based upon 'bikeid' and 'gender'
bike_groups = bike_trips_df.groupby(['bikeid','gender'])

# Create a new variable that holds the sum of our groups
sum_it_up = bike_groups.sum()
sum_it_up.head(12)
# Out:
#                  tripduration
# bikeid   gender
# SEA00001 Female     15876.665
#          Male       41150.373
#          Other        276.880
# SEA00005 Female     20616.240
#          Male       60386.328
#          Other       1784.955
# SEA00006 Female     20071.004
#          Male       46584.453
#          Other       1469.839
# SEA00007 Female      9996.402
#          Male       16618.213
#          Other       1040.571

# %%
# Make a variable called bike_id and store a 'bikeid' in it
bike_id = "SEA00001"

# Collect the trips of the 'bikeid' above
just_one_bike = sum_it_up.loc[bike_id]

# Place the gender keys for that single bike into a list
gender_list = just_one_bike.keys()

# Create a pie chart based upon the trip duration of that single bike
bike_pie = just_one_bike.plot(kind="pie", y=gender_list, title=("Trips of " + bike_id))
# [0]
#bike_pie = just_one_bike.plot(kind="pie", y='tripduration', title=("Trips of " + bike_id))
#bike_pie = just_one_bike.plot(kind="pie", title=("Trips of " + bike_id), subplots=True)
#explode = (0, 0.1, 0)
#bike_pie = just_one_bike.plot(kind="pie", title=("Trips of " + bike_id), subplots=True, explode=explode)

#plt.tight_layout()
#plt.axis("equal") # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-7dd320e1ed00> in <module>
#       9
#      10 # Create a pie chart based upon the trip duration of that single bike
# ---> 11 bike_pie = just_one_bike.plot(kind="pie", y=gender_list, title=("Trips of " + bike_id))
#      12 # [0]
#      13 #bike_pie = just_one_bike.plot(kind="pie", y='tripduration', title=("Trips of " + bike_id))
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     804                     # converted to series actually. copy to not modify
#     805                     data = data[y].copy()
# --> 806                     data.index.name = y
#     807         elif isinstance(data, ABCDataFrame):
#     808             data_cols = data.columns
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexes/base.py in name(self, value)
#    1192                 "'MultiIndex.set_names' instead."
#    1193             )
# -> 1194         maybe_extract_name(value, None, type(self))
#    1195         self._name = value
#    1196
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexes/base.py in maybe_extract_name(name, obj, cls)
#    5403     # GH#29069
#    5404     if not is_hashable(name):
# -> 5405         raise TypeError(f"{cls.__name__}.name must be a hashable type")
#    5406
#    5407     return name
#
# TypeError: Index.name must be a hashable type
